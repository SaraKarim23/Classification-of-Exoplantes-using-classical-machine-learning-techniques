# %% [markdown]
# <a href="https://colab.research.google.com/github/SaraKarim23/Classification-of-Exoplantes-using-classical-machine-learning-techniques/blob/main/Classification_of_Exoplantes_using_classical_machine_learning_techniques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install shutup
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting shutup
#   Downloading shutup-0.2.0-py3-none-any.whl (1.5 kB)
# Installing collected packages: shutup
# Successfully installed shutup-0.2.0

# %%
import shutup; shutup.please()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

from sklearn import  metrics
from sklearn.metrics import accuracy_score,plot_confusion_matrix,precision_score,recall_score,f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve,roc_auc_score,plot_roc_curve

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from lightgbm import LGBMClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier



from scipy import ndimage

from sklearn import tree

# %matplotlib inline

# %%
train_df = pd.read_csv('/content/drive/MyDrive/ExoPlanet/exoTrain.csv')
train_df.head()
# Out:
#    LABEL   FLUX.1   FLUX.2   FLUX.3   FLUX.4   FLUX.5   FLUX.6  FLUX.7  \
# 0      2    93.85    83.81    20.10   -26.98   -39.56  -124.71 -135.18
# 1      2   -38.88   -33.83   -58.54   -40.09   -79.31   -72.81  -86.55
# 2      2   532.64   535.92   513.73   496.92   456.45   466.00  464.50
# 3      2   326.52   347.39   302.35   298.13   317.74   312.70  322.33
# 4      2 -1107.21 -1112.59 -1118.95 -1095.10 -1057.55 -1034.48 -998.34
#
#     FLUX.8  FLUX.9  ...  FLUX.3188  FLUX.3189  FLUX.3190  FLUX.3191  \
# 0   -96.27  -79.89  ...     -78.07    -102.15    -102.15      25.13
# 1   -85.33  -83.97  ...      -3.28     -32.21     -32.21     -24.89
# 2   486.39  436.56  ...     -71.69      13.31      13.31     -29.89
# 3   311.31  312.42  ...       5.71      -3.73      -3.73      30.05
# 4 -1022.71 -989.57  ...    -594.37    -401.66    -401.66    -357.24
#
#    FLUX.3192  FLUX.3193  FLUX.3194  FLUX.3195  FLUX.3196  FLUX.3197
# 0      48.57      92.54      39.32      61.42       5.08     -39.54
# 1      -4.86       0.76     -11.70       6.46      16.00      19.93
# 2     -20.88       5.06     -11.80     -28.91     -70.02     -96.67
# 3      20.03     -12.67      -8.77     -17.31     -17.35      13.98
# 4    -443.76    -438.54    -399.71    -384.65    -411.79    -510.54
#
# [5 rows x 3198 columns]

# %%
val_df = pd.read_csv('/content/drive/MyDrive/ExoPlanet/exoTest.csv')
val_df
# Out:
#      LABEL   FLUX.1   FLUX.2   FLUX.3   FLUX.4   FLUX.5   FLUX.6   FLUX.7  \
# 0        2   119.88   100.21    86.46    48.68    46.12    39.39    18.57
# 1        2  5736.59  5699.98  5717.16  5692.73  5663.83  5631.16  5626.39
# 2        2   844.48   817.49   770.07   675.01   605.52   499.45   440.77
# 3        2  -826.00  -827.31  -846.12  -836.03  -745.50  -784.69  -791.22
# 4        2   -39.57   -15.88    -9.16    -6.37   -16.13   -24.05    -0.90
# ..     ...      ...      ...      ...      ...      ...      ...      ...
# 565      1   374.46   326.06   319.87   338.23   251.54   209.84   186.35
# 566      1    -0.36     4.96     6.25     4.20     8.26    -9.53   -10.10
# 567      1   -54.01   -44.13   -41.23   -42.82   -39.47   -24.88   -31.14
# 568      1    91.36    85.60    48.81    48.69    70.05    22.30    11.63
# 569      1  3071.19  2782.53  2608.69  2325.47  2089.37  1769.56  1421.09
#
#       FLUX.8   FLUX.9  ...  FLUX.3188  FLUX.3189  FLUX.3190  FLUX.3191  \
# 0       6.98     6.63  ...      14.52      19.29      14.44      -1.62
# 1    5569.47  5550.44  ...    -581.91    -984.09   -1230.89   -1600.45
# 2     362.95   207.27  ...      17.82     -51.66     -48.29     -59.99
# 3    -746.50  -709.53  ...     122.34      93.03      93.03      68.81
# 4     -45.20    -5.04  ...     -37.87     -61.85     -27.15     -21.18
# ..       ...      ...  ...        ...        ...        ...        ...
# 565   167.46   135.45  ...    -123.55    -166.90    -222.44    -209.71
# 566    -4.54   -11.55  ...     -12.40      -5.99     -17.94     -11.96
# 567   -24.71   -13.12  ...      -0.73      -1.64       1.58      -4.82
# 568    37.86    28.27  ...       2.44      11.53     -16.42     -17.86
# 569  1142.09   902.31  ...     695.41     865.97     882.41    1203.06
#
#      FLUX.3192  FLUX.3193  FLUX.3194  FLUX.3195  FLUX.3196  FLUX.3197
# 0        13.33      45.50      31.93      35.78     269.43      57.72
# 1     -1824.53   -2061.17   -2265.98   -2366.19   -2294.86   -2034.72
# 2       -82.10    -174.54     -95.23    -162.68     -36.79      30.63
# 3         9.81      20.75      20.25    -120.81    -257.56    -215.41
# 4       -33.76     -85.34     -81.46     -61.98     -69.34     -17.84
# ..         ...        ...        ...        ...        ...        ...
# 565    -180.16    -166.83    -235.66    -213.63    -205.99    -194.07
# 566     -12.11     -13.68      -3.59      -5.32     -10.98     -11.24
# 567     -11.93     -17.14      -4.25       5.47      14.46      18.70
# 568      21.10     -10.25     -37.06      -8.43      -6.48      17.60
# 569    1293.03    1354.41    -192.81    -277.22     -69.63     121.56
#
# [570 rows x 3198 columns]

# %%
train_df.describe().T
# Out:
#             count        mean           std        min     25%   50%     75%  \
# LABEL      5087.0    1.007273      0.084982       1.00   1.000  1.00   1.000
# FLUX.1     5087.0  144.505445  21506.686590 -227856.26 -42.340 -0.71  48.255
# FLUX.2     5087.0  128.577834  21797.167583 -315440.76 -39.520 -0.89  44.285
# FLUX.3     5087.0  147.134789  21913.092010 -284001.76 -38.505 -0.74  42.325
# FLUX.4     5087.0  156.151203  22233.659938 -234006.87 -35.050 -0.40  39.765
# ...           ...         ...           ...        ...     ...   ...     ...
# FLUX.3193  5087.0  655.303147  53399.785963 -502889.37 -24.405  3.50  30.855
# FLUX.3194  5087.0 -494.784966  17844.469520 -775322.00 -26.760 -0.68  18.175
# FLUX.3195  5087.0 -544.594264  17722.339334 -732006.00 -24.065  0.36  18.770
# FLUX.3196  5087.0 -440.239100  16273.406292 -700992.00 -21.135  0.90  19.465
# FLUX.3197  5087.0 -300.536399  14459.795577 -643170.00 -19.820  1.43  20.280
#
#                  max
# LABEL            2.0
# FLUX.1     1439240.5
# FLUX.2     1453319.0
# FLUX.3     1468429.0
# FLUX.4     1495750.0
# ...              ...
# FLUX.3193  3616292.0
# FLUX.3194   288607.5
# FLUX.3195   215972.0
# FLUX.3196   207590.0
# FLUX.3197   211302.0
#
# [3198 rows x 8 columns]

# %%
val_df.describe().T
# Out:
#            count        mean           std       min      25%    50%      75%  \
# LABEL      570.0    1.008772      0.093329      1.00   1.0000  1.000   1.0000
# FLUX.1     570.0  515.411351  12592.950138 -59421.00 -22.2300  1.195  98.3175
# FLUX.2     570.0  738.046404  12622.940170 -14663.43 -22.9125  0.410  89.7100
# FLUX.3     570.0  532.603246  12545.065255 -56580.00 -22.9850 -1.125  89.8275
# FLUX.4     570.0  739.618088  12591.933126 -10817.59 -18.6625 -0.880  73.2575
# ...          ...         ...           ...       ...      ...    ...      ...
# FLUX.3193  570.0  291.509561   9654.581767 -90595.00 -18.2725  7.150  35.8100
# FLUX.3194  570.0  256.656789   9362.719825 -86719.07 -24.0000 -4.385  17.7550
# FLUX.3195  570.0  121.810035   9487.642217 -86911.50 -27.3600 -4.995  11.7450
# FLUX.3196  570.0  224.806035   9483.948248 -87123.26 -36.8550 -5.135  12.2650
# FLUX.3197  570.0  133.954544   9700.731923 -87476.94 -29.4750 -3.785  13.2050
#
#                 max
# LABEL           2.0
# FLUX.1     290882.5
# FLUX.2     290653.5
# FLUX.3     290554.0
# FLUX.4     290486.5
# ...             ...
# FLUX.3193  205924.0
# FLUX.3194  203193.0
# FLUX.3195  205050.0
# FLUX.3196  206884.5
# FLUX.3197  211488.5
#
# [3198 rows x 8 columns]

# %%
fig = plt.figure(figsize=(15,40))
plt.title('Stars with Exoplanets')
for i in range(12):
    ax = fig.add_subplot(14,4,i+1)
    train_df[train_df['LABEL']==2].iloc[i,1:].hist(bins=40)

# %%
fig = plt.figure(figsize=(15,40))
plt.title('Stars without Exoplanets')
for i in range(12):
    ax = fig.add_subplot(14,4,i+1)
    train_df[train_df['LABEL']==1].iloc[i,1:].hist(bins=40)

# %%
fig = plt.figure(figsize=(15,40))
plt.title('Stars with Exoplanets')
for i in range(12):
    ax = fig.add_subplot(14,4,i+1)
    ax.scatter(np.arange(3197),train_df[train_df['LABEL'] == 2].iloc[i,1:],s=1)

# %%
fig = plt.figure(figsize=(15,40))
plt.title('Stars without Exoplanets')
for i in range(12):
    ax = fig.add_subplot(14,4,i+1)
    ax.scatter(np.arange(3197),train_df[train_df['LABEL']==1].iloc[i,1:],s=1)

# %%
minima = train_df.iloc[:,1:].min(axis=1)
maxima = train_df.iloc[:,1:].max(axis=1)

# %%
plt.figure(figsize=(20,5))
plt.title('Minimum flux value of each stars')
plt.xlabel('Index number of stars')
plt.ylabel('Minimum Flux values')
plt.plot(np.arange(len(minima)),minima)

# %%
plt.figure(figsize=(20,5))
plt.title('Maximum flux value of each stars')
plt.xlabel('Index number of stars')
plt.ylabel('Maximum flux values')
plt.plot(np.arange(len(maxima)),maxima)

# %%
train_X = train_df.drop('LABEL',axis = 1)
val_X = val_df.drop('LABEL',axis =1)

# %%
print("Shape of Training X :",train_X.shape)
print("Shape of Validation X :",val_X.shape)
# Out:
# Shape of Training X : (5087, 3197)
# Shape of Validation X : (570, 3197)

# %%
train_y = train_df['LABEL'].values
val_y = val_df['LABEL'].values

# %%
print("Shape of Training y :",train_y.shape)
print("Shape of Validation y :",val_y.shape)
# Out:
# Shape of Training y : (5087,)
# Shape of Validation y : (570,)

# %% [markdown]
# **Model Building**

# %% [markdown]
# Naive Bayes Classifier

# %%
nb = GaussianNB()
nb.fit(train_X,train_y)
print('Attempting to fit Bernouli Naive Bayes Classifier')
# Out:
# Attempting to fit Bernouli Naive Bayes Classifier

# %%
# %%time
y_pred_val_nb = nb.predict(val_X)
print('Accuracy on Validation set :',accuracy_score(val_y, y_pred_val_nb))
print("\n")
print(classification_report(val_y, y_pred_val_nb))
# Out:
# Accuracy on Validation set : 0.02456140350877193
#
#
#               precision    recall  f1-score   support
#
#            1       1.00      0.02      0.03       565
#            2       0.01      1.00      0.02         5
#
#     accuracy                           0.02       570
#    macro avg       0.50      0.51      0.02       570
# weighted avg       0.99      0.02      0.03       570
#
# CPU times: user 52.5 ms, sys: 1.99 ms, total: 54.5 ms
# Wall time: 54.2 ms

# %%
print('Confusion Matrix: \n',metrics.ConfusionMatrixDisplay.from_predictions(val_y, y_pred_val_nb))
# Out:
# Confusion Matrix:
#  <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7f48e7c40b10>

# %%
print('Normalized Confusion Matrix:\n',metrics.ConfusionMatrixDisplay.from_predictions(val_y, y_pred_val_nb,normalize='all'))
# Out:
# Normalized Confusion Matrix:
#  <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7f48e88d68d0>

# %% [markdown]
# Logistic Regression

# %%
lr = LogisticRegression()
lr.fit(train_X,train_y)
print('Attempting to fit Logistic Regressor')
# Out:
# Attempting to fit Logistic Regressor

# %%
# %%time
y_pred_val_lr = lr.predict(val_X)
print('Accuracy on Validation set :',accuracy_score(val_y, y_pred_val_lr))
print("\n")
print(classification_report(val_y, y_pred_val_lr))
# Out:
# Accuracy on Validation set : 0.5596491228070175
#
#
#               precision    recall  f1-score   support
#
#            1       0.99      0.56      0.72       565
#            2       0.01      0.40      0.02         5
#
#     accuracy                           0.56       570
#    macro avg       0.50      0.48      0.37       570
# weighted avg       0.98      0.56      0.71       570
#
# CPU times: user 40.7 ms, sys: 7.96 ms, total: 48.6 ms
# Wall time: 39.6 ms

# %%
print('Confusion Matrix: \n',metrics.ConfusionMatrixDisplay.from_predictions(val_y, y_pred_val_lr))
# Out:
# Confusion Matrix:
#  <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7f48e8023f10>

# %%
print('Normalized Confusion Matrix:\n',metrics.ConfusionMatrixDisplay.from_predictions(val_y, y_pred_val_lr,normalize='all'))
# Out:
# Normalized Confusion Matrix:
#  <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7f48e8b25bd0>

# %% [markdown]
# Support Vector Classifier

# %%
svm = LinearSVC()
svm.fit(train_X,train_y)
print('Attempting to fit Logistic Regressor')
# Out:
# Attempting to fit Logistic Regressor

# %%
# %%time
y_pred_val_svm = svm.predict(val_X)
print('Accuracy on Validation set :',accuracy_score(val_y, y_pred_val_svm))
print("\n")
print(classification_report(val_y, y_pred_val_svm))
# Out:
# Accuracy on Validation set : 0.6333333333333333
#
#
#               precision    recall  f1-score   support
#
#            1       0.99      0.63      0.77       565
#            2       0.01      0.60      0.03         5
#
#     accuracy                           0.63       570
#    macro avg       0.50      0.62      0.40       570
# weighted avg       0.99      0.63      0.77       570
#
# CPU times: user 43.7 ms, sys: 10.1 ms, total: 53.8 ms
# Wall time: 41 ms

# %%
print('Confusion Matrix: \n',metrics.ConfusionMatrixDisplay.from_predictions(val_y, y_pred_val_svm))
# Out:
# Confusion Matrix:
#  <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7f48e7526c10>

# %%
print('Normalized Confusion Matrix:\n',metrics.ConfusionMatrixDisplay.from_predictions(val_y, y_pred_val_svm,normalize='all'))
# Out:
# Normalized Confusion Matrix:
#  <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7f48e76f0310>

# %% [markdown]
# KNN Classifier

# %%
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(train_X,train_y)
print('Attempting to fit KNN Classifier')
# Out:
# Attempting to fit KNN Classifier

# %%
# %%time
y_pred_val_knn = knn.predict(val_X)
print('Accuracy on Validation set :',accuracy_score(val_y, y_pred_val_knn))
print("\n")
print(classification_report(val_y, y_pred_val_knn))
# Out:
# Accuracy on Validation set : 0.9912280701754386
#
#
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      1.00       565
#            2       0.00      0.00      0.00         5
#
#     accuracy                           0.99       570
#    macro avg       0.50      0.50      0.50       570
# weighted avg       0.98      0.99      0.99       570
#
# CPU times: user 1.19 s, sys: 63.1 ms, total: 1.26 s
# Wall time: 675 ms

# %%
print('Confusion Matrix: \n',metrics.ConfusionMatrixDisplay.from_predictions(val_y, y_pred_val_knn))
# Out:
# Confusion Matrix:
#  <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7f48e8a13a50>

# %%
print('Normalized Confusion Matrix:\n',metrics.ConfusionMatrixDisplay.from_predictions(val_y, y_pred_val_knn,normalize='all'))
# Out:
# Normalized Confusion Matrix:
#  <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7f48e7a92c10>

# %% [markdown]
# Decision Tree Classifier

# %%
dc = DecisionTreeClassifier(random_state = 0)
dc.fit(train_X,train_y)
print('Attempting to fit Decision Tree Classifier')
# Out:
# Attempting to fit Decision Tree Classifier

# %%
# %%time
y_pred_val_dc = dc.predict(val_X)
print('Accuracy on Validation set :',accuracy_score(val_y, y_pred_val_dc))
print("\n")
print(classification_report(val_y, y_pred_val_dc))
# Out:
# Accuracy on Validation set : 0.9824561403508771
#
#
#               precision    recall  f1-score   support
#
#            1       0.99      0.99      0.99       565
#            2       0.14      0.20      0.17         5
#
#     accuracy                           0.98       570
#    macro avg       0.57      0.59      0.58       570
# weighted avg       0.99      0.98      0.98       570
#
# CPU times: user 37.8 ms, sys: 0 ns, total: 37.8 ms
# Wall time: 37.6 ms

# %%
print('Confusion Matrix: \n',metrics.ConfusionMatrixDisplay.from_predictions(val_y, y_pred_val_dc))
# Out:
# Confusion Matrix:
#  <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7f48e8645910>

# %%
print('Normalized Confusion Matrix:\n',metrics.ConfusionMatrixDisplay.from_predictions(val_y, y_pred_val_dc,normalize='all'))
# Out:
# Normalized Confusion Matrix:
#  <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7f48e8645f50>

# %% [markdown]
# Random Forest Classifier

# %%
rf = RandomForestClassifier()
rf.fit(train_X,train_y)
print('Attempting to fit Random Forest Classifier')
# Out:
# Attempting to fit Random Forest Classifier

# %%
# %%time
y_pred_val_rf = rf.predict(val_X)
print('Accuracy on Validation set :',accuracy_score(val_y, y_pred_val_rf))
print("\n")
print(classification_report(val_y, y_pred_val_rf))
# Out:
# Accuracy on Validation set : 0.9912280701754386
#
#
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      1.00       565
#            2       0.00      0.00      0.00         5
#
#     accuracy                           0.99       570
#    macro avg       0.50      0.50      0.50       570
# weighted avg       0.98      0.99      0.99       570
#
# CPU times: user 52.7 ms, sys: 1.97 ms, total: 54.7 ms
# Wall time: 54.4 ms

# %%
print('Confusion Matrix: \n',metrics.ConfusionMatrixDisplay.from_predictions(val_y, y_pred_val_rf))
# Out:
# Confusion Matrix:
#  <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7f48e7b8e2d0>

# %%
print('Normalized Confusion Matrix:\n',metrics.ConfusionMatrixDisplay.from_predictions(val_y, y_pred_val_rf,normalize='all'))
# Out:
# Normalized Confusion Matrix:
#  <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7f48e74dbf90>

# %% [markdown]
# MLP Classifier

# %%
mlp = MLPClassifier(max_iter = 300)
mlp.fit(train_X,train_y)
print('Attempting to fit MLP Classifier')
# Out:
# Attempting to fit MLP Classifier

# %%
# %%time
y_pred_val_mlp = mlp.predict(val_X)
print('Accuracy on Validation set :',accuracy_score(val_y, y_pred_val_mlp))
print("\n")
print(classification_report(val_y, y_pred_val_mlp))
# Out:
# Accuracy on Validation set : 0.9526315789473684
#
#
#               precision    recall  f1-score   support
#
#            1       0.99      0.96      0.98       565
#            2       0.08      0.40      0.13         5
#
#     accuracy                           0.95       570
#    macro avg       0.54      0.68      0.55       570
# weighted avg       0.99      0.95      0.97       570
#
# CPU times: user 66.6 ms, sys: 11.3 ms, total: 77.9 ms
# Wall time: 58.2 ms

# %%
print('Confusion Matrix: \n',metrics.ConfusionMatrixDisplay.from_predictions(val_y, y_pred_val_mlp))
# Out:
# Confusion Matrix:
#  <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7f48e82b8910>

# %%
print('Normalized Confusion Matrix:\n',metrics.ConfusionMatrixDisplay.from_predictions(val_y, y_pred_val_mlp,normalize='all'))
# Out:
# Normalized Confusion Matrix:
#  <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7f48e7aa6cd0>

# %% [markdown]
# Gradient Boosting Classifier

# %%
gbc = GradientBoostingClassifier()
gbc.fit(train_X,train_y)
print('Attempting to fit Gradient Boosting Classifier')
# Out:
# Attempting to fit Gradient Boosting Classifier

# %%
# %%time
y_pred_val_gbc = gbc.predict(val_X)
print('Accuracy on Validation set :',accuracy_score(val_y, y_pred_val_gbc))
print("\n")
print(classification_report(val_y, y_pred_val_gbc))
# Out:
# Accuracy on Validation set : 0.9912280701754386
#
#
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      1.00       565
#            2       0.00      0.00      0.00         5
#
#     accuracy                           0.99       570
#    macro avg       0.50      0.50      0.50       570
# weighted avg       0.98      0.99      0.99       570
#
# CPU times: user 53.9 ms, sys: 41 µs, total: 53.9 ms
# Wall time: 55.1 ms

# %%
print('Confusion Matrix: \n',metrics.ConfusionMatrixDisplay.from_predictions(val_y, y_pred_val_gbc))
# Out:
# Confusion Matrix:
#  <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7f48e84e89d0>

# %%
print('Normalized Confusion Matrix:\n',metrics.ConfusionMatrixDisplay.from_predictions(val_y, y_pred_val_gbc,normalize='all'))
# Out:
# Normalized Confusion Matrix:
#  <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7f48e7fce710>

# %% [markdown]
# Light GBM Classifier

# %%
lgbm = LGBMClassifier()
lgbm.fit(train_X,train_y)
print('Attempting to fit Light GBM Classifier')
# Out:
# Attempting to fit Light GBM Classifier

# %%
# %%time
y_pred_val_lgbm = lgbm.predict(val_X)
print('Accuracy on Validation set :',accuracy_score(val_y, y_pred_val_lgbm))
print("\n")
print(classification_report(val_y, y_pred_val_lgbm))
# Out:
# Accuracy on Validation set : 0.9912280701754386
#
#
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      1.00       565
#            2       0.00      0.00      0.00         5
#
#     accuracy                           0.99       570
#    macro avg       0.50      0.50      0.50       570
# weighted avg       0.98      0.99      0.99       570
#
# CPU times: user 84.8 ms, sys: 2.03 ms, total: 86.8 ms
# Wall time: 73.2 ms

# %%
print('Confusion Matrix: \n',metrics.ConfusionMatrixDisplay.from_predictions(val_y, y_pred_val_lgbm))
# Out:
# Confusion Matrix:
#  <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7f48e84e8590>

# %%
print('Normalized Confusion Matrix:\n',metrics.ConfusionMatrixDisplay.from_predictions(val_y, y_pred_val_lgbm,normalize='all'))
# Out:
# Normalized Confusion Matrix:
#  <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x7f48e7fba0d0>

# %% [markdown]
# Accuracy of all Models on Validation Set

# %%
print('Accuracy of Naive Bayes on Validation set :',accuracy_score(val_y, y_pred_val_nb))
print('\nAccuracy of Logistic Regression on Validation set :',accuracy_score(val_y, y_pred_val_lr))
print('\nAccuracy of KNN Classifier on Validation set :',accuracy_score(val_y, y_pred_val_knn))
print('\nAccuracy of Support Vector on Validation set :',accuracy_score(val_y, y_pred_val_svm))
print('\nAccuracy of Decision Tree on Validation set :',accuracy_score(val_y, y_pred_val_dc))
print('\nAccuracy of Random Forest on Validation set :',accuracy_score(val_y, y_pred_val_rf))
print('\nAccuracy of MLP Classifier on Validation set :',accuracy_score(val_y, y_pred_val_mlp))
print('\nAccuracy of Gradient Boosting Classifier on Validation set :',accuracy_score(val_y, y_pred_val_gbc))
print('\nAccuracy Light GBM Classifier on Validation set :',accuracy_score(val_y, y_pred_val_lgbm))
# Out:
# Accuracy of Naive Bayes on Validation set : 0.02456140350877193
#
# Accuracy of Logistic Regression on Validation set : 0.5596491228070175
#
# Accuracy of KNN Classifier on Validation set : 0.9912280701754386
#
# Accuracy of Support Vector on Validation set : 0.6333333333333333
#
# Accuracy of Decision Tree on Validation set : 0.9824561403508771
#
# Accuracy of Random Forest on Validation set : 0.9912280701754386
#
# Accuracy of MLP Classifier on Validation set : 0.9526315789473684
#
# Accuracy of Gradient Boosting Classifier on Validation set : 0.9912280701754386
#
# Accuracy Light GBM Classifier on Validation set : 0.9912280701754386

# %% [markdown]
# As we can see our top 3 Models are -
#
#     1. MLP Classifier
#
#     2. Gradient Boosting Classifier
#
#     3. Light GBM Classifier

# %% [markdown]
# Future Scope -
#
#     1. Applying Principal Component Analysis for selecting most important flux components.
#     2. Applying Synthetic Minority Oversampling Technique (SMOTE) for imbalanced class treatment.
#     3. Trying Advanced Neural Network Models.
